# %% [markdown]
# ### [문제1]

# %%
import pandas as pd

x = ['가', '나', '다', '라', '마']
y = [10, 20, 30, 40, 50]

sample = pd.Series(y, x)
sample
# Out:
# 가    10
# 나    20
# 다    30
# 라    40
# 마    50
# dtype: int64

# %% [markdown]
# ### [문제2]

# %%
import numpy as np

np.random.seed(20)
sample2 = pd.Series(np.random.randint(100, 200, size=(15, )))
print(sample2[sample2 <= 160])
# Out:
# 2     115
# 4     128
# 6     109
# 7     120
# 9     122
# 11    134
# 13    140
# dtype: int32

# %% [markdown]
# ### [문제3]

# %%
x = ['가', '나', '다', '라', '마']
y = ['apple', np.nan, 'banana', 'kiwi', 'gubong']

sample3 = pd.Series(y, x)
sample3
# Out:
# 가     apple
# 나       NaN
# 다    banana
# 라      kiwi
# 마    gubong
# dtype: str

# %% [markdown]
# ### [문제4]

# %%
sample3[sample3.notnull()]
# Out:
# 가     apple
# 다    banana
# 라      kiwi
# 마    gubong
# dtype: str

# %% [markdown]
# ### [문제5]

# %%
sample3[sample3.isnull()]
# Out:
# 나    NaN
# dtype: str

# %% [markdown]
# ### [문제6]

# %%
np.random.seed(0)
sample = pd.Series(np.random.randint(100, 200, size=(10, )))
sample[2:7]
# Out:
# 2    164
# 3    167
# 4    167
# 5    109
# 6    183
# dtype: int32

# %% [markdown]
# ### [문제7]

# %%
np.random.seed(0)
sample2 = pd.Series(np.random.randint(100, 200, size=(10, )),
                    index=list('가나다라마바사아자차'))
sample2
# Out:
# 가    144
# 나    147
# 다    164
# 라    167
# 마    167
# 바    109
# 사    183
# 아    121
# 자    136
# 차    187
# dtype: int32

# %%
# (1)
sample2['바':]
# Out:
# 바    109
# 사    183
# 아    121
# 자    136
# 차    187
# dtype: int32

# %%
# (2)
sample2[:'다']
# Out:
# 가    144
# 나    147
# 다    164
# dtype: int32

# %%
# (3)
sample2['나':'바']
# Out:
# 나    147
# 다    164
# 라    167
# 마    167
# 바    109
# dtype: int32
